# %% [markdown]
# # Capstone 2 - Youtube API and related queries

# %%
## Youtube (YT) query setup
from datetime import datetime
today = datetime.today()

# %%
api_key = 'AIzaSyAZQIsx0XaXIBpBdtl9gfPY_15x99A5EZE'  # tom's API key
from apiclient.discovery import build
youtube = build('youtube', 'v3', developerKey=api_key)
type(youtube)
# Out:
# googleapiclient.discovery.Resource

# %%
#req = youtube.search().list(q='corey schafer jupyter notebooks',part='snippet', type='video',maxResults=50)

# %%
#query = ('P1', 'python tutorial') 
query = ('P2', 'python reading CSV files')
#query = ('P3', 'python pandas dataframes')
#query = ('P4', 'python lists')
#query = ('P5', 'python dictionaries')
#query = ('P6', 'python sort functions')
#query = ('P7', 'python for Loops')
#query = ('P8', 'python tuples')

# =============================================================================
# Search Query Initialisation
# =============================================================================
#query = 'corey schafer python jupyter notebook'

query_results = youtube.search().list(
        part = 'snippet',
        q = query[1],
        order = 'relevance', # You can consider using viewCount
        maxResults = 50,
        type = 'video', # Channels might appear in search results
        relevanceLanguage = 'en',
        safeSearch = 'moderate',
        ).execute()

#req = youtube.search().list(q='avengers',part='snippet', type='video',maxResults=50)

# %%
len(query_results)
# Out:
# 6

# %%
len(query_results['items'])
# Out:
# 50

# %%
query_results
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/dxl0fl_nz3qQAAt_OUcSlhfAmn8"',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'US',
#  'pageInfo': {'totalResults': 262318, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/vYoTDDUxWhQdm2RbAvYk8gSYDm8"',
#    'id': {'kind': 'youtube#video', 'videoId': 'q5uM4VKywbA'},
#    'snippet': {'publishedAt': '2017-08-09T16:00:06.000Z',
#     'channelId': 'UCCezIgC97PvUuR4_gbFUs5g',
#     'title': 'Python Tutorial: CSV Module - How to Read, Parse, and Write CSV Files',
#     'description': 'In this Python Programming Tutorial, we will be learning how to work with csv files using the csv module. We will learn how to read, parse, and write to csv files.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/q5uM4VKywbA/default.jpg',
#       'width': 120,
#       'height': 90},
# ...

# %%
#video_ids = list(map(lambda x:x ['snippet']['resourceId']['videoId'],videos))

# %%
# =============================================================================
# Get Video IDs
# =============================================================================
video_id = []
channel = []
video_title = []
video_desc = []
video_age = []
search_rank = []
x=1
for item in query_results['items']:
    video_id.append(item['id']['videoId'])
    channel.append(item['snippet']['channelTitle'])
    video_title.append(item['snippet']['title'])
    video_desc.append(item['snippet']['description'])
    video_date = datetime.strptime(item['snippet']['publishedAt'],'%Y-%m-%dT%H:%M:%S.%fZ') 
    date_delta = (today - video_date).days
    video_age.append(date_delta//7)
    search_rank.append(x)
    x += 1

# %%
print(video_id)
# Out:
# ['rfscVS0vtbw', '_uQrJ0TkZlc', 'Z1Yd7upQsXY', 'f79MRyMsjrQ', 'kLZuut1fYzQ', 'H1elmMBnykA', 'vaysJAMDaZw', 'N4mEzFDjqtA', '5mJ_Qftw2_0', 'ZDa-Z5JzLYM', '8DvywoWv6fI', 'apACNr7DC_s', 'C6jJg9Zan7w', 'bZ6NL59FMoc', '9Os0o3wzS_I', 'NSbOtYzIQI0', 'pJ3IPRqiD2M', 'W8KRzm-HUcc', 'mNdbcHECGN4', '3cZsjOclmoM', 'kDdTgxv2Vv0', 'CD4qAhfFuLo', 'cpPG0bKHYKc', 'v_S64kldryc', '5sqye64-1-k', 'uPwztoPBVWI', '0Lt9w-BxKFQ', 'JT80XhYJdBw', 'CtbckFw0pJs', 'P1vH3Pfw6BI', 'jFCNu1-Xdsw', 'RpseX2ylEuw', 'wfcWRAxRVBA', 'udO6gSLXujU', 'hEgO047GxaQ', 'YfO28Ihehbk', 'Eaz5e6M8tL4', 'J_Cy_QjG6NE', 'Q59X518JZHE', 'Z1RJmh_OqeA', 'QUT1VHiLmmI', 'IEEhzQoKtQU', '5GYeia8IRbg', '6a39OjkCN5I', 'YgI94IRXySk', 'psaDHhZ0cPs', 'chPhlsHoEPo', 'IZ0IM_T4aio', 'l9v1ewQXv5M', 'N0lxfilGfak']

# %%
# Out:
# 50

# %%
for i in range(0,len(video_id)):#  video_id:
    print(f'search rank: {search_rank[i]} video id: {video_id[i]} channel: {channel[i]} video age: {video_age[i]} video_title: {video_title[i]}')  # video_desc: {video_desc[i]}')
# Out:
# search rank: 1 video id: rfscVS0vtbw channel: freeCodeCamp.org video age: 64 video_title: Learn Python - Full Course for Beginners [Tutorial]
# search rank: 2 video id: _uQrJ0TkZlc channel: Programming with Mosh video age: 33 video_title: Python Tutorial for Beginners [Full Course] 2019
# search rank: 3 video id: Z1Yd7upQsXY channel: CS Dojo video age: 92 video_title: Python Tutorial for Absolute Beginners #1 - What Are Variables?
# search rank: 4 video id: f79MRyMsjrQ channel: Programming with Mosh video age: 50 video_title: Python Tutorial for Programmers - Python Crash Course
# search rank: 5 video id: kLZuut1fYzQ channel: CS Dojo video age: 67 video_title: What Can You Do with Python? - The 3 Main Applications
# search rank: 6 video id: H1elmMBnykA channel: Derek Banas video age: 6 video_title: Python Tutorial 2019
# ...

# %%
for i in range(0,len(video_id),50):
        test_id = ','.join(video_id[i:i+50])
        print(f'TestID: {test_id}')
# Out:
# TestID: rfscVS0vtbw,_uQrJ0TkZlc,Z1Yd7upQsXY,f79MRyMsjrQ,kLZuut1fYzQ,H1elmMBnykA,vaysJAMDaZw,N4mEzFDjqtA,5mJ_Qftw2_0,ZDa-Z5JzLYM,8DvywoWv6fI,apACNr7DC_s,C6jJg9Zan7w,bZ6NL59FMoc,9Os0o3wzS_I,NSbOtYzIQI0,pJ3IPRqiD2M,W8KRzm-HUcc,mNdbcHECGN4,3cZsjOclmoM,kDdTgxv2Vv0,CD4qAhfFuLo,cpPG0bKHYKc,v_S64kldryc,5sqye64-1-k,uPwztoPBVWI,0Lt9w-BxKFQ,JT80XhYJdBw,CtbckFw0pJs,P1vH3Pfw6BI,jFCNu1-Xdsw,RpseX2ylEuw,wfcWRAxRVBA,udO6gSLXujU,hEgO047GxaQ,YfO28Ihehbk,Eaz5e6M8tL4,J_Cy_QjG6NE,Q59X518JZHE,Z1RJmh_OqeA,QUT1VHiLmmI,IEEhzQoKtQU,5GYeia8IRbg,6a39OjkCN5I,YgI94IRXySk,psaDHhZ0cPs,chPhlsHoEPo,IZ0IM_T4aio,l9v1ewQXv5M,N0lxfilGfak

# %%
#
#video_id_test = 'HW29067qVWk,YJC6ldI3hWk,jCzT9XFZ5bw,RSl87lqOXDE,daefaLgNkw0'
# get video stats
#for item in video_id:
#    print(f'video id: {video_id}')
#res_stats = youtube.videos().list(id=video_id_test, part='statistics').execute()
res_stats = youtube.videos().list(id=test_id, part='statistics').execute()
#video_id2 = 'HW29067qVWk,YJC6ldI3hWk,jCzT9XFZ5bw,RSl87lqOXDE,daefaLgNkw0'
#res_test = youtube.videos().list(id=video_id2, part='statistics').execute()

# %%
res_stats
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/hFc8EHOGv5QRqPX1q1fI7hVMfyY"',
#  'pageInfo': {'totalResults': 50, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#video',
#    'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/ussUdqXoBpr_-AxKo4Wqug6vToI"',
#    'id': 'rfscVS0vtbw',
#    'statistics': {'viewCount': '9046471',
#     'likeCount': '211943',
#     'dislikeCount': '2715',
#     'favoriteCount': '0',
#     'commentCount': '12012'}},
#   {'kind': 'youtube#video',
#    'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/hoEmjGaZtiW4nni4qD6nqQa0Wcg"',
#    'id': '_uQrJ0TkZlc',
#    'statistics': {'viewCount': '4849453',
#     'likeCount': '178573',
#     'dislikeCount': '1255',
#     'favoriteCount': '0',
#     'commentCount': '12023'}},
#   {'kind': 'youtube#video',
#    'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/CgaSQWbW5knS1KHeoa7-cHXnKEI"',
#    'id': 'Z1Yd7upQsXY',
#    'statistics': {'viewCount': '3595094',
#     'likeCount': '70957',
#     'dislikeCount': '1131',
# ...

# %%
video_id
# Out:
# ['rfscVS0vtbw',
#  '_uQrJ0TkZlc',
#  'Z1Yd7upQsXY',
#  'f79MRyMsjrQ',
#  'kLZuut1fYzQ',
#  'H1elmMBnykA',
#  'vaysJAMDaZw',
#  'N4mEzFDjqtA',
#  '5mJ_Qftw2_0',
#  'ZDa-Z5JzLYM',
#  '8DvywoWv6fI',
#  'apACNr7DC_s',
#  'C6jJg9Zan7w',
#  'bZ6NL59FMoc',
#  '9Os0o3wzS_I',
#  'NSbOtYzIQI0',
#  'pJ3IPRqiD2M',
#  'W8KRzm-HUcc',
#  'mNdbcHECGN4',
#  '3cZsjOclmoM',
#  'kDdTgxv2Vv0',
#  'CD4qAhfFuLo',
#  'cpPG0bKHYKc',
#  'v_S64kldryc',
#  '5sqye64-1-k',
#  'uPwztoPBVWI',
#  '0Lt9w-BxKFQ',
#  'JT80XhYJdBw',
#  'CtbckFw0pJs',
#  'P1vH3Pfw6BI',
#  'jFCNu1-Xdsw',
#  'RpseX2ylEuw',
#  'wfcWRAxRVBA',
#  'udO6gSLXujU',
#  'hEgO047GxaQ',
#  'YfO28Ihehbk',
#  'Eaz5e6M8tL4',
#  'J_Cy_QjG6NE',
#  'Q59X518JZHE',
#  'Z1RJmh_OqeA',
#  'QUT1VHiLmmI',
#  'IEEhzQoKtQU',
#  '5GYeia8IRbg',
#  '6a39OjkCN5I',
#  'YgI94IRXySk',
#  'psaDHhZ0cPs',
#  'chPhlsHoEPo',
#  'IZ0IM_T4aio',
#  'l9v1ewQXv5M',
#  'N0lxfilGfak']

# %%
# =============================================================================
# Populate to Dataframe
# =============================================================================
import pandas as pd

output_dict = {
        'Query Num': query[0],
        'Query': query[1],
        'Search Rank': search_rank,
        'Channel': channel,
        'Video ID': video_id,
        'Video Title': video_title,
        'Video Description': video_desc,
        'Video Age': video_age
        }

output_df = pd.DataFrame(output_dict, columns = output_dict.keys())

#video_id = []
#channel = []
#video_title = []
#video_desc = []

# %%
output_df
# Out:
#    Query Num            Query  Search Rank                   Channel  \
# 0         P1  python tutorial            1          freeCodeCamp.org
# 1         P1  python tutorial            2     Programming with Mosh
# 2         P1  python tutorial            3                   CS Dojo
# 3         P1  python tutorial            4     Programming with Mosh
# 4         P1  python tutorial            5                   CS Dojo
# 5         P1  python tutorial            6               Derek Banas
# 6         P1  python tutorial            7                  edureka!
# 7         P1  python tutorial            8               Derek Banas
# 8         P1  python tutorial            9                  TechLead
# 9         P1  python tutorial           10             Corey Schafer
# 10        P1  python tutorial           11          freeCodeCamp.org
# 11        P1  python tutorial           12                 Socratica
# 12        P1  python tutorial           13          freeCodeCamp.org
# ...

# %%
for item in res_stats['items']:
    #print(item['id'],item['statistics'])
    if len(item['statistics']) == 5:
        print(item['id'],item['statistics']['viewCount'],item['statistics']['likeCount'],item['statistics']['dislikeCount'],item['statistics']['commentCount'])
    else: 
        print('Comments Disabled: ', item['id'],item['statistics']['viewCount'])
# Out:
# rfscVS0vtbw 9046471 211943 2715 12012
# _uQrJ0TkZlc 4849453 178573 1255 12023
# Z1Yd7upQsXY 3595094 70957 1131 4655
# f79MRyMsjrQ 360909 6558 184 601
# kLZuut1fYzQ 1540528 45080 684 1507
# H1elmMBnykA 40305 1434 15 393
# vaysJAMDaZw 525448 9329 178 305
# N4mEzFDjqtA 5159331 69537 1662 6480
# 5mJ_Qftw2_0 282919 12501 324 911
# ZDa-Z5JzLYM 1435988 37120 242 1900
# 8DvywoWv6fI 610011 23108 194 867
# apACNr7DC_s 436437 12006 284 642
# C6jJg9Zan7w 110068 2182 33 495
# bZ6NL59FMoc 186260 2811 61 106
# 9Os0o3wzS_I 381034 6452 106 402
# NSbOtYzIQI0 763158 10497 163 1384
# pJ3IPRqiD2M 305176 11936 248 494
# W8KRzm-HUcc 353400 8551 46 488
# mNdbcHECGN4 102393 2483 76 170
# 3cZsjOclmoM 168973 1964 84 129
# kDdTgxv2Vv0 88671 2272 42 199
# CD4qAhfFuLo 157086 1816 66 188
# cpPG0bKHYKc 2742700 11754 765 1191
# v_S64kldryc 513373 12088 390 802
# 5sqye64-1-k 540944 11535 300 604
# uPwztoPBVWI 73704 711 7 92
# 0Lt9w-BxKFQ 45219 635 21 152
# JT80XhYJdBw 55680 3075 43 154
# ...

# %%
for item in res_stats['items']:
    #print(item['id'],item['statistics'])
    print(item['id'],item['statistics'], len(item['statistics'])) #['viewCount'],item['statistics']['likeCount'],item['statistics']['dislikeCount'],item['statistics']['commentCount'])

#for item in res_stats['items']:
#   print(len(item['statistics']))
# Out:
# rfscVS0vtbw {'viewCount': '9046471', 'likeCount': '211943', 'dislikeCount': '2715', 'favoriteCount': '0', 'commentCount': '12012'} 5
# _uQrJ0TkZlc {'viewCount': '4849453', 'likeCount': '178573', 'dislikeCount': '1255', 'favoriteCount': '0', 'commentCount': '12023'} 5
# Z1Yd7upQsXY {'viewCount': '3595094', 'likeCount': '70957', 'dislikeCount': '1131', 'favoriteCount': '0', 'commentCount': '4655'} 5
# f79MRyMsjrQ {'viewCount': '360909', 'likeCount': '6558', 'dislikeCount': '184', 'favoriteCount': '0', 'commentCount': '601'} 5
# kLZuut1fYzQ {'viewCount': '1540528', 'likeCount': '45080', 'dislikeCount': '684', 'favoriteCount': '0', 'commentCount': '1507'} 5
# H1elmMBnykA {'viewCount': '40305', 'likeCount': '1434', 'dislikeCount': '15', 'favoriteCount': '0', 'commentCount': '393'} 5
# vaysJAMDaZw {'viewCount': '525448', 'likeCount': '9329', 'dislikeCount': '178', 'favoriteCount': '0', 'commentCount': '305'} 5
# ...

# %%
# =============================================================================
# Get Video IDs
# =============================================================================
video_id_stats = []
viewCount = []
likeCount = []
dislikeCount = []
commentCount = []
for item in res_stats['items']:
    if len(item['statistics']) == 5:
        video_id_stats.append(item['id'])
        viewCount.append(item['statistics']['viewCount'])
        likeCount.append(item['statistics']['likeCount'])
        dislikeCount.append(item['statistics']['dislikeCount'])
        commentCount.append(item['statistics']['commentCount'])
    else:
        video_id_stats.append(item['id'])
        viewCount.append(item['statistics']['viewCount'])
        likeCount.append(0)
        dislikeCount.append(0)
        commentCount.append(0)
#if len(item['statistics']) == 5:
#        print(item['id'],item['statistics']['viewCount'],item['statistics']['likeCount'],item['statistics']['dislikeCount'],item['statistics']['commentCount'])
#    else: 
#        print('Comments Disabled: ', item['id'],item['statistics']['viewCount'])

# %%
output_dict_stats = {
        'Video ID': video_id_stats,
        'view count': viewCount,
        'like count': likeCount,
        'dislike count': dislikeCount,
        'comment count': commentCount
        }

output_df_stats = pd.DataFrame(output_dict_stats, columns = output_dict_stats.keys())

# %%
output_df_stats
# Out:
#        Video ID view count like count dislike count comment count
# 0   rfscVS0vtbw    9046471     211943          2715         12012
# 1   _uQrJ0TkZlc    4849453     178573          1255         12023
# 2   Z1Yd7upQsXY    3595094      70957          1131          4655
# 3   f79MRyMsjrQ     360909       6558           184           601
# 4   kLZuut1fYzQ    1540528      45080           684          1507
# 5   H1elmMBnykA      40305       1434            15           393
# 6   vaysJAMDaZw     525448       9329           178           305
# 7   N4mEzFDjqtA    5159331      69537          1662          6480
# 8   5mJ_Qftw2_0     282919      12501           324           911
# 9   ZDa-Z5JzLYM    1435988      37120           242          1900
# 10  8DvywoWv6fI     610011      23108           194           867
# 11  apACNr7DC_s     436437      12006           284           642
# 12  C6jJg9Zan7w     110068       2182            33           495
# ...

# %%
output_df_stats = output_df.merge(output_df_stats, left_on='Video ID', right_on='Video ID', how = 'left')
output_df_stats
# Out:
#    Query Num            Query  Search Rank                   Channel  \
# 0         P1  python tutorial            1          freeCodeCamp.org
# 1         P1  python tutorial            2     Programming with Mosh
# 2         P1  python tutorial            3                   CS Dojo
# 3         P1  python tutorial            4     Programming with Mosh
# 4         P1  python tutorial            5                   CS Dojo
# 5         P1  python tutorial            6               Derek Banas
# 6         P1  python tutorial            7                  edureka!
# 7         P1  python tutorial            8               Derek Banas
# 8         P1  python tutorial            9                  TechLead
# 9         P1  python tutorial           10             Corey Schafer
# 10        P1  python tutorial           11          freeCodeCamp.org
# 11        P1  python tutorial           12                 Socratica
# 12        P1  python tutorial           13          freeCodeCamp.org
# ...

# %%
# =============================================================================
# Get Comments of Top Videos
# =============================================================================
video_id_pop = []
channel_pop = []
video_num_pop = []
video_title_pop = []
video_desc_pop = []
comments_pop = []
comment_id_pop = []
reply_count_pop = []
like_count_pop = []

from tqdm import tqdm
for i, video in enumerate(tqdm(video_id, ncols = 100)):
    response = youtube.commentThreads().list(
                    part = 'snippet',
                    videoId = video,
                    maxResults = 100, # Only take top 100 comments...
                    order = 'relevance', #... ranked on relevance
                    textFormat = 'plainText',
                    ).execute()
    
    comments_temp = []
    comment_id_temp = []
    reply_count_temp = []
    like_count_temp = []
    for item in response['items']:
        comments_temp.append(item['snippet']['topLevelComment']['snippet']['textDisplay'])
        comment_id_temp.append(item['snippet']['topLevelComment']['id'])
        reply_count_temp.append(item['snippet']['totalReplyCount'])
        like_count_temp.append(item['snippet']['topLevelComment']['snippet']['likeCount'])
        video_num_pop.append(str(i+1))
    comments_pop.extend(comments_temp)
    comment_id_pop.extend(comment_id_temp)
    reply_count_pop.extend(reply_count_temp)
    like_count_pop.extend(like_count_temp)
    
    #video_num_pop.extend([str([i]+1)]*len(comments_temp))
    #test_pop.extend(str(i+1)* len(comments_temp))
    #video_num_pop.extend(str(i+1)* len(comments_temp))
    video_id_pop.extend([video_id[i]]*len(comments_temp))
    channel_pop.extend([channel[i]]*len(comments_temp))
    video_title_pop.extend([video_title[i]]*len(comments_temp))
    video_desc_pop.extend([video_desc[i]]*len(comments_temp))
    
#query_pop_id = [query][0] * len(video_id_pop)
#query_pop = [query][1] * len(video_id_pop)
# Out:
# 100%|███████████████████████████████████████████████████████████████| 50/50 [00:28<00:00,  1.54it/s]

# %%
#len(video_num_pop)
len(video_id_pop)
# Out:
# 4437

# %%
response
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/mJ3S-fayk3T5avQIpeq_R4c7IKk"',
#  'nextPageToken': '...',
#  'pageInfo': {'totalResults': 100, 'resultsPerPage': 100},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/D8R4s7LEOi-z3m2YaVH0shm-gzY"',
#    'id': 'UgxSmmId_uDGl_PiSYJ4AaABAg',
#    'snippet': {'videoId': 'N0lxfilGfak',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"p4VTdlkQv3HQeTEaXgvLePAydmU/PMwX1V-06PGmmc6-ATD-BsCQyvE"',
#      'id': 'UgxSmmId_uDGl_PiSYJ4AaABAg',
#      'snippet': {'authorDisplayName': 'edureka!',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AGF-l7-9PG8SfKpaC78Y2uJojhcSxlnP8dRmqNVkPw=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCkw4JCwteGrDHIsyIIKo4tQ',
#       'authorChannelId': {'value': 'UCkw4JCwteGrDHIsyIIKo4tQ'},
#       'videoId': 'N0lxfilGfak',
# ...

# %%
# =============================================================================
# Populate to Dataframe
# =============================================================================
import pandas as pd

output_dict_comments = {
        'Query Num': query[0], #_pop_id,
        'Query': query[1],
        'Channel': channel_pop,
        'Video Num': video_num_pop,
        'Video ID': video_id_pop,
        'Video Title': video_title_pop,
        'Video Description': video_desc_pop,
        'Comment': comments_pop,
        'Comment ID': comment_id_pop,
        'Replies': reply_count_pop,
        'Likes': like_count_pop,
        }

output_df_comments = pd.DataFrame(output_dict_comments, columns = output_dict_comments.keys())

# %%
output_df_comments
# Out:
#      Query Num            Query           Channel Video Num     Video ID  \
# 0           P1  python tutorial  freeCodeCamp.org         1  rfscVS0vtbw
# 1           P1  python tutorial  freeCodeCamp.org         1  rfscVS0vtbw
# 2           P1  python tutorial  freeCodeCamp.org         1  rfscVS0vtbw
# 3           P1  python tutorial  freeCodeCamp.org         1  rfscVS0vtbw
# 4           P1  python tutorial  freeCodeCamp.org         1  rfscVS0vtbw
# 5           P1  python tutorial  freeCodeCamp.org         1  rfscVS0vtbw
# 6           P1  python tutorial  freeCodeCamp.org         1  rfscVS0vtbw
# 7           P1  python tutorial  freeCodeCamp.org         1  rfscVS0vtbw
# 8           P1  python tutorial  freeCodeCamp.org         1  rfscVS0vtbw
# 9           P1  python tutorial  freeCodeCamp.org         1  rfscVS0vtbw
# 10          P1  python tutorial  freeCodeCamp.org         1  rfscVS0vtbw
# 11          P1  python tutorial  freeCodeCamp.org         1  rfscVS0vtbw
# ...

# %%
output_df_comments.to_excel('P1_query.xlsx')
output_df_stats.to_excel('P1_stats.xlsx')

# %%
lst = ['query1', 'query2', 'query3', 'query4', 'query5', 'query6', 'query7', 'query8']

for i, value in enumerate(lst):
    print(f'I: {i} value: {value}')
    # i is the enumeration index
    # value is the entry in list
# Out:
# I: 0 value: query1
# I: 1 value: query2
# I: 2 value: query3
# I: 3 value: query4
# I: 4 value: query5
# I: 5 value: query6
# I: 6 value: query7
# I: 7 value: query8

# %%
from datetime import date
f_date = date(2019, 1, 1)      # YYYY, MM, DD
l_date = date(2019, 12, 31)
delta = l_date - f_date
print(round(delta.days/7,2))
# Out:
# 52.0

# %%
# Putting in correct format for YT API
#start_time = datetime(year=2005, month=1, day=1).strftime('%Y-%m-%dT%H:%M:%SZ')
#end_time = datetime(year=2008, month=1, day=1).strftime('%Y-%m-%dT%H:%M:%SZ')
from datetime import datetime

test_time = '2016-09-22T16:30:00.000Z'
test_time_obj = datetime.strptime(test_time,'%Y-%m-%dT%H:%M:%S.%fZ')

today = datetime.today()
print(type(test_time_obj))
print(test_time_obj)
print(today)
print(today - test_time_obj)
delta = (today - test_time_obj).days
print(delta, delta//7)
# Out:
# <class 'datetime.datetime'>
# 2016-09-22 16:30:00
# 2019-10-05 21:14:19.500029
# 1108 days, 4:44:19.500029
# 1108 158
